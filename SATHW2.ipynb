# %%
# Q3: import random  # Import the random module to make random selections.

# def monty_hall(simulations=10000):
#    """
#    Simulates the Monty Hall problem.
#    
#    Args:
#    simulations (int): The number of times the simulation will run.
#    
#    Returns:
#    tuple: (win_by_switching, win_by_staying) - probabilities of winning by switching or staying.
#    """
#    
#    win_by_switching = 0  # Counter for wins when the player switches doors.
#    win_by_staying = 0    # Counter for wins when the player stays with the initial choice.
#
#    # Loop through the number of simulations
#    for _ in range(simulations):
#        # Randomly place the car behind one of the 3 doors (0, 1, 2).
#        car_position = random.randint(0, 2)
#        
#        # Player randomly selects one of the doors (0, 1, 2).
#        player_choice = random.randint(0, 2)
#        
#        # Host opens one of the remaining doors that does not have the car.
#        remaining_doors = [door for door in range(3) if door != player_choice and door != car_position]
#        door_opened_by_host = random.choice(remaining_doors)
#        
#        # The other door that the player did not choose and the host did not open.
#        switch_choice = [door for door in range(3) if door != player_choice and door != door_opened_by_host][0]
#
#        # Check if switching wins.
#        if switch_choice == car_position:
#            win_by_switching += 1
#
#        # Check if staying wins.
#        if player_choice == car_position:
#            win_by_staying += 1
#
#    # Calculate the probabilities.
#    win_by_switching_prob = win_by_switching / simulations
#    win_by_staying_prob = win_by_staying / simulations
#
#    return win_by_switching_prob, win_by_staying_prob
#
#
# Run the simulation with 10,000 iterations
# switching_prob, staying_prob = monty_hall()
#
# print(f"Probability of winning by switching: {switching_prob:.4f}")
# print(f"Probability of winning by staying: {staying_prob:.4f}")
#
# Summary:
# The code simulates the Monty Hall problem, where a car is hidden behind one of three doors, and the player must choose a 
# door. The host then opens another door that doesn't contain the car. The player is given the option to either switch to 
# the remaining unopened door or stay with their initial choice.
#
# Key steps in the code:
# 1. Import the `random` module for making random selections.
# 2. Define the `monty_hall` function, which takes the number of simulations as input (default is 10,000).
# 3. Initialize counters to track wins when switching and staying.
# 4. Run a loop for the specified number of simulations:
#    - Randomly place the car behind one of the three doors.
#    - The player randomly selects a door.
#    - The host opens a door that does not have the car and wasn't picked by the player.
#    - Determine the door to which the player would switch. 
#    - Check if switching or staying wins and update counters accordingly.
# 5. Calculate and return the probabilities of winning by switching and staying.
# 6. Print the results, demonstrating that switching doors generally results in a higher probability of winning (about 2/3) 
# compared to staying (about 1/3).

# Chat Logs:
# https://chatgpt.com/share/66eb91a8-daa0-8012-a410-9f72c1d40bb1

# %%
# Q6:
# 1. I understand that it takes some time for the bot to comprehend what the given prompt is, but it as fairly quick with
# responding, considering the amount of code it provided with its comments. The chatbot is fairly fast considering the 
# amount of web it has to surf to conjure the answer to the prompts.
# 2. The code provided to me was detailed enough for me to understand the procedure with the comments, considering the fact
# I am new to Python. I wasn't frustrated with the way the chatbot answered my questions and prompts. I would
# consider the chatbot helpful in coding because I tested the python on wing 101 to make sure it was accurate to what I was
# asking of it. 
# 3. I think that chatbots are pretty helpful for generating code as long as the code follows the prompt and its rules;
# however, the code is based off the input from the user. I believe there can be error from the chatbots no matter the 
# specificity input from the user, but its overall usefulness is execellent when trying to understand the code when you ask
# the bot for explainations for each line.

# %%
# Q7:
# I think it's good to use chatbots to assist in understanding potential lines of code; however, using them without trying 
# to understand how each line works defeats the purpose of using the chatbot to create code. I have only been to one STA130
# class so far because of my late enrollment, but my previous experience with chatbots in highschool made me believe it 
# should only be used to understand and give potential to the user.
